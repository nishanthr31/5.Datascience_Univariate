# %%
from Univariate import univariate
import pandas as pd
dataset = pd.read_csv("Placement.csv")
Qual,Quan = univariate.qualquan(dataset)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset['ssc_p'].mean()
# Out:
# 67.30339534883721

# %%
dataset['ssc_p'].median()
# Out:
# 67.0

# %%
dataset['ssc_p'].mode()[0]
# Out:
# 62.0

# %%
Descriptive = pd.DataFrame(index = ["Mean", "Median", "Mode"],columns = Quan)
Descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %% [markdown]
# # Central Tendency

# %%
#Colums - first,Rows - second 
Descriptive["etest_p"]["Mean"] = 9
# Out:
# C:\Users\nravi378\AppData\Local\Temp\ipykernel_4272\3143067636.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Descriptive["etest_p"]["Mean"] = 9

# %%
Descriptive.index
# Out:
# Index(['Mean', 'Median', 'Mode'], dtype='object')

# %%
Descriptive.columns
# Out:
# Index(['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'], dtype='object')

# %%
for i in Descriptive.columns :
     Descriptive[i]["Mean"] = dataset[i].mean()
     Descriptive[i]["Median"] = dataset[i].median()
     Descriptive[i]["Mode"] = dataset[i].mode()[0] 
    
           
Descriptive
# Out:
# C:\Users\nravi378\AppData\Local\Temp\ipykernel_4272\2764224632.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Descriptive[i]["Mean"] = dataset[i].mean()
# ...

# %%
for i in Descriptive.columns :
    for j in Descriptive.index :
        if(j=="Mean"):
            Descriptive[i][j] = dataset[i].mean()
        elif(j=="Median"):
            Descriptive[i][j] = dataset[i].median()
        else:
            Descriptive[i][j] = dataset[i].mode()[0] 

Descriptive
# Out:
# C:\Users\nravi378\AppData\Local\Temp\ipykernel_4272\3597432925.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Descriptive[i][j] = dataset[i].mean()
# ...
