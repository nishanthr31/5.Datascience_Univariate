# %%
import pandas as pd
dataset=pd.read_csv("PreProcessed_data.csv")
dataset
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status  sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# ...

# %%
import seaborn as sns
sns.distplot(dataset["ssc_p"])
# Out:
# C:\Users\nravi378\AppData\Local\Temp\ipykernel_23256\3471076516.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["ssc_p"])
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
from matplotlib import pyplot
from scipy.stats import norm
import seaborn as sns
ax = sns.distplot(dataset["ssc_p"],kde=True,kde_kws={"color": "blue"},color = "yellow")
pyplot.axvline(40,color="black")
pyplot.axvline(90,color="black")

sample=dataset["ssc_p"]
mean = sample.mean()
std = sample.std()

dist = norm(mean,std)

values = [value for value in range(40,90)]
Probability = [dist.pdf(value) for value in values]

Prob = sum(Probability)
print("The area density of range from {} to {} : {}".format(40,90,Prob) )
# Out:
# The area density of range from 40 to 90 : 0.9747549934033221
# C:\Users\nravi378\AppData\Local\Temp\ipykernel_23256\1399109037.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset["ssc_p"],kde=True,kde_kws={"color": "blue"},color = "yellow")

# %%
def get_pdf_graph(dataset,start,end):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={"color": "blue"},color = "yellow")
    pyplot.axvline(start,color="black")
    pyplot.axvline(end,color="black")
    
    sample=dataset
    mean = sample.mean()
    std = sample.std()
    
    dist = norm(mean,std)
    
    values = [value for value in range(start,end)]
    Probability = [dist.pdf(value) for value in values]
    
    Prob = sum(Probability)
    print("The area density of range from {} to {} : {}".format(start,end,Prob) )
    return Prob

# %%
get_pdf_graph(dataset["ssc_p"],60,80)
# Out:
# The area density of range from 60 to 80 : 0.6346413295441957
# C:\Users\nravi378\AppData\Local\Temp\ipykernel_23256\1200597729.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={"color": "blue"},color = "yellow")
# 0.6346413295441957

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset["hsc_p"])
ecdf(56)
# Out:
# 0.14418604651162792

# %%
def standard_normal_distribution(dataset):
    sample=dataset
    mean = sample.mean()
    std = sample.std()
    values = [value for value in dataset]
    Single_value = [i for i in values]
    Z_score = [(Single_value - mean)/std]
    import seaborn as sns
    sns.distplot( Z_score)

# %%
standard_normal_distribution(dataset["hsc_p"])
# Out:
# C:\Users\nravi378\AppData\Local\Temp\ipykernel_23256\4000100021.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( Z_score)
